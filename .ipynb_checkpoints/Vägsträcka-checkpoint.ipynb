# %%
import folium
from folium.plugins import HeatMap
import geopandas as gpd
file = gpd.read_file(r'C:\Users\debbi\Downloads\Rv80_Veistrekning')

# %%
file['geometry'].values[0]
# Out:
# <LINESTRING (474139 7463649, 474116 7463636, 474048 7463622, 473954 7463603,...>
